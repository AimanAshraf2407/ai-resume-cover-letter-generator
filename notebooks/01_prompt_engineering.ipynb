# %%
import sys
from pathlib import Path

# Add the parent directory (project root) to sys.path
sys.path.append(str(Path.cwd().parent))

import json
from models.generator import generate_resume, generate_cover_letter

# Load profile and job posting
with open("../data/sample_profiles/profile_01_software_engineer.json") as f:
    user_profile = json.dumps(json.load(f), indent=2)

with open("../data/sample_job_descriptions/job_01_junior_ai_engineer.txt") as f:
    job_description = f.read()

# Test generation
resume_output = generate_resume(user_profile, job_description)
cover_letter_output = generate_cover_letter(user_profile, job_description)

print("Generated Resume:\n", resume_output)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Generated Resume:
#  # Alex Chen
# **Location:** Kuala Lumpur, Malaysia
# **Email:** alex.chen@example.com | **Phone:** +60 12-345 6789
# **LinkedIn:** linkedin.com/in/alexchen-dev | **GitHub:** github.com/alexchen-dev
#
# ---
#
# ## Professional Summary
# Detail-oriented **Junior AI / Software Engineer** with hands-on experience building scalable RESTful backend microservices in Python (FastAPI) and integrating Large Language Model (LLM) APIs. Proven capability in prompt engineering, frontend-backend integration, and database optimization. Adept at leveraging tools like Git and Docker within collaborative engineering teams to deploy performant, AI-driven application features.
#
# ---
#
# ...
